# %% [markdown]
# ### For each of the following questions, outline how you could use an A/B test to find an answer. Be sure to identify all five key components of an A/B test we outlined above.
#
# **Two versions** of something whose effects will be compared. Typically one version is a "control version," often already in use (or "no intervention"), and one is a "test version," which has some changes from the control. That change is often called the treatment. If starting from scratch, however, you may have two different test versions to compare to each other.
#
# **A sample**, divided into two groups. Each sample should be selected so that it is similar to the population you want to understand. The groups should be similar to one another so that any differences between them can be attributed to seeing version A or version B and not something else. You also want the split of between A and B to be as random as possible.
#
# **A hypothesis**. Your hypothesis is what you expect to happen. For example, "I expect the HTML email will achieve a higher open and conversion rate than the plain text email."
#
# **Outcome(s) of interest**. What you expect will change as a result of using version A or version B, and how you will measure that change. This means you have to decide on a key metric, which should capture the effect of your change and reflect the motivations for the test in the first place.
#
# **Other measured variables**. This includes information about the two groups that can be used to ensure they are similar, as well as secondary outcomes that are less important than the primary outcomes of interest but which might also change in response to using version A or version B.
#
#     **A hypothesis**
#
#     **Outcome(s) of interest**
#
#     **Two versions**
#
#     **A sample**
#
#     **Other measured variables**
#
# #### 1. Does a new supplement help people sleep better?
#
#   **A hypothesis**
#
#             Taking new sleep supplement increases users feeling of restfulness, when taken.
#   **Outcome(s) of interest**
#
#             People feel more rested than normal. Key metric total REM sleep.
#   **Two versions**
#
#             Take to populations give 1 the new supplements, give the other the current best supplement. Measure the relevent variables that define "better sleep" or "restfulness". Repeat experiement with a placebo if new supplement performs as good or worse than the current best supplement.
#
#   **A sample**
#
#             The sample for this supplement is important, because certain groups are going to be more biased towards outcomes. Consider that we took a truely random subset of the population. The outcomes could be skewed in the sense that not all people feel the need to sleep better.
#
#
#   **Other measured variables**
#
#     Age
#     gender
#     location,
#     time sleep start
#     time REM start
#     time awake
#     Time of last meal (was alcohol consumed?)
#     Night time ambient decible conditions
#     Night time ambient light conditions
#     Preferred initial Sleeping position
#
#
# #### 2. Will new uniforms help a gym's business?
#
#    **A hypothesis**
#     New employee uniforms can help boost
#    **Outcome(s) of interest**
#
#    **Two versions**
#
#    **A sample**
#
#    **Other measured variables**
#
# #### 3. Will a new homepage improve my online exotic pet rental business?
#
#    **A hypothesis**
#         A new homepage will boost time spent on the website or boost orders.
#
#    **Outcome(s) of interest**
#         More people that use the new website are more likely to make a purchase. Key metric - Increase in sales
#
#    **Two versions**
#         Set up a random redirect for incomming users to the initial homepage and monitor user activity between users who use the new website and users that use the old website.
#
#    **A sample**
#         The sample here is limited by the webtraffic to the first redirect site.
#
#    **Other measured variables**
#
#         Time spent on homepage
#         number of sites visited with in the web portal
#         products viewed
#
#
# #### 4. If I put 'please read' in the email subject will more people read my emails?
#
#    **A hypothesis**
#     Using 'please read' in the email subject will cause people to read my emails more frequently.
#
#    **Outcome(s) of interest**
#     Assuming that the e-mails require a response the response rate of my email will rise.
#
#     Key metric - increase in e-mails being read.
#
#    **Two versions**
#     Send e-mails with and with out please read in the subject line.
#
#    **A sample**
#
#    **Other measured variables**
#
#        Time e-mail sent
#
#
# ## DRILL: Am I Biased?
#
#     1. You're testing advertising emails for a bathing suit company and you test one version of the email in February and the other in May.
#
#         Customers may be more inclined to buy something for warm weather, when it's warm or when they are going somewhere it is warm, or they are making a purchase for themselves in the future. Depending on the hemisphere your recipient is in, the recipiant could be during winter/rainy seasons and thus be biased based on weather. This can be more complicated if your samples coherts are not co-located
#
#     2. You open a clinic to treat anxiety and find that the people who visit show a higher rate of anxiety than the general population.
#
#     Either you suck at your job (hopefully not), or you've selected for the very patient you're tring to help and therefore good at targeting the people that need it and not the ones that don't.
#
#     3. You launch a new ad billboard based campaign and see an increase in website visits in the first week.
#
#     Either people saw the ad campaign and are responding to it, or there was an atypical increase in traffic atributed by an unknown variable.
#
#     4. You launch a loyalty program but see no change in visits in the first week.
#
#     How was the loyalty program rolled out? Which consumer did it target, existing or new customers? Maybe the value propisition to the customer is not what they want.
